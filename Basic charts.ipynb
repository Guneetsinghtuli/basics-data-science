# %%
from matplotlib import pyplot as plt

# %%
movies = ["west side story", "The playlist", "The Beautiful mind","Dr. No"]
num_oscars = [2,4,6,1]
xs = [i + 0.1 for i, _ in enumerate(movies)]

# %%
plt.ylabel("Number of Oscars")
plt.title("Hello")
# Out:
# Text(0.5, 1.0, 'Hello')

# %%
plt.bar(xs,num_oscars)
plt.xticks([i + 0.1 for i, _ in enumerate(movies)], movies,rotation='vertical')
plt.show()
